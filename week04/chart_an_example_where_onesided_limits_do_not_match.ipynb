# %% [markdown]
# # Chart: An Example Where One-Sided Limits Do Not Match

# %%
plt.plot([-5, 0], [1, 1], color="b", label="f(x)")
plt.plot([0, 5], [2, 2], color="b")

plt.legend()
plt.xlim(-5, 5)
plt.ylim(0, 3)
plt.title(r"$\lim_{x \to 0^-} f(x)=1$ vs $\lim_{x \to 0^+} f(x)=3$")
plt.show();
