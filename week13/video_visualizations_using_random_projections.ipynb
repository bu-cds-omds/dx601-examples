# %% [markdown]
# # Video: Visualizations using Random Projections
#
# This video shows visualizations of the Palmer Penguins data set using random projections.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.options.mode.copy_on_write = True

# %%
penguins_adelie = pd.read_csv("https://portal.edirepository.org/nis/dataviewer?packageid=knb-lter-pal.219.3&entityid=002f3893385f710df69eeebe893144ff", index_col="Sample Number")
penguins_gentoo = pd.read_csv("https://portal.edirepository.org/nis/dataviewer?packageid=knb-lter-pal.220.3&entityid=e03b43c924f226486f2f0ab6709d2381", index_col="Sample Number")
penguins_chinstrap = pd.read_csv("https://portal.edirepository.org/nis/dataviewer?packageid=knb-lter-pal.221.2&entityid=fe853aa8f7a59aa84cdd3197619ef462", index_col="Sample Number")
penguins = pd.concat([penguins_adelie, penguins_gentoo, penguins_chinstrap])

# %%
penguins.describe()
# Out:
#        Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# count          342.000000         342.000000           342.000000
# mean            43.921930          17.151170           200.915205
# std              5.459584           1.974793            14.061714
# min             32.100000          13.100000           172.000000
# 25%             39.225000          15.600000           190.000000
# 50%             44.450000          17.300000           197.000000
# 75%             48.500000          18.700000           213.000000
# max             59.600000          21.500000           231.000000
#
#        Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# count     342.000000         330.000000         331.000000
# mean     4201.754386           8.733382         -25.686292
# std       801.954536           0.551770           0.793961
# min      2700.000000           7.632200         -27.018540
# 25%      3550.000000           8.299890         -26.320305
# ...

# %%
projection_columns = ['Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)']

# %%
projection = np.random.normal(size=(4, 2))
projection.shape
# Out:
# (4, 2)

# %%
penguins_projected = penguins[projection_columns] @ projection
penguins_projected.shape
# Out:
# (344, 2)

# %%
penguins_projected.iloc[:,0]
# Out:
# Sample Number
# 1    -1636.892404
# 2    -1660.697607
# 3    -1414.264511
# 4             NaN
# 5    -1501.337769
#          ...
# 64   -1746.728657
# 65   -1480.826409
# 66   -1649.000025
# 67   -1791.701555
# 68   -1648.032116
# Name: 0, Length: 344, dtype: float64

# %%
plt.scatter(penguins_projected.iloc[:,0], penguins_projected.iloc[:,1], alpha=0.2)
None

# %%
#color_map = dict(zip(penguins["Species"].unique(), plt.rcParams['axes.prop_cycle'].by_key()["color"]))
color_map = {"Adelie Penguin (Pygoscelis adeliae)": "blue",
             "Gentoo penguin (Pygoscelis papua)": "orange",
             "Chinstrap penguin (Pygoscelis antarctica)": "green"}
color_map
# Out:
# {'Adelie Penguin (Pygoscelis adeliae)': 'blue',
#  'Gentoo penguin (Pygoscelis papua)': 'orange',
#  'Chinstrap penguin (Pygoscelis antarctica)': 'green'}

# %%
def try_projection():
    projection = np.random.normal(size=(4, 2))
    penguins_projected = penguins[projection_columns].to_numpy() @ projection

    penguins_plot = penguins[["Species"]]
    penguins_plot["p0"] = penguins_projected[:,0]
    penguins_plot["p1"] = penguins_projected[:,1]
    penguins_plot["color"] = penguins["Species"].map(color_map)

    penguins_plot.plot.scatter("p0", "p1", alpha=0.2, c="color")
    None

# %%
try_projection()

# %%
try_projection()

# %%
try_projection()

# %%
try_projection()

# %%
try_projection()

# %%
try_projection()

# %%
try_projection()
